# %% [markdown]
# ## Curve25519

# %%
from sage.schemes.elliptic_curves.constructor import EllipticCurve_from_Weierstrass_polynomial
R.<x,y> = QQ[]
E = EllipticCurve_from_Weierstrass_polynomial(-x^2 + y^3 + 486662 * y^2 + y)
E.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Secp256k1

# %%
from sage.schemes.elliptic_curves.constructor import EllipticCurve_from_Weierstrass_polynomial
R.<x,y> = QQ[]
# y^2 = x^3+0x+7
E = EllipticCurve_from_Weierstrass_polynomial(-x^2 + y^3 + 0 * y + 7)
E.plot()
# Out:
# Graphics object consisting of 1 graphics primitive
